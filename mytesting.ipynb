# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import pandas as pd
ds = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv")
#print(ds.to_string())
plt.plot([12,34,5,6,7], [34,45,23,12,45], marker='o', linestyle='-', color='b', label='Data Points')
plt.title("Simple Line Chart")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()
